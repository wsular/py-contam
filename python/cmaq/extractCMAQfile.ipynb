# %%
import numpy as np

# %%
years = np.arange(2086, 2096)
months = np.arange(1,13)

for year in years:
    for month in months:
        fn  = 'cmaq5.2/rcp8.5/extr/2040ei_v6_cb05v2_ref_RCP8.5.combine.aconc.' + str(year) + '.' + str(month).zfill(2)
        print('Processing: ' + fn)
        cmd = 'tar -xvf /Volumes/Untitled/cmaq5.2.tar --directory /Volumes/sdata/cmaq/ ' + fn
        ! $cmd
# Out:
# Processing: cmaq5.2/rcp8.5/extr/2040ei_v6_cb05v2_ref_RCP8.5.combine.aconc.2086.01
# cmaq5.2/rcp8.5/extr/2040ei_v6_cb05v2_ref_RCP8.5.combine.aconc.2086.01
# Processing: cmaq5.2/rcp8.5/extr/2040ei_v6_cb05v2_ref_RCP8.5.combine.aconc.2086.02
# cmaq5.2/rcp8.5/extr/2040ei_v6_cb05v2_ref_RCP8.5.combine.aconc.2086.02
# Processing: cmaq5.2/rcp8.5/extr/2040ei_v6_cb05v2_ref_RCP8.5.combine.aconc.2086.03
# cmaq5.2/rcp8.5/extr/2040ei_v6_cb05v2_ref_RCP8.5.combine.aconc.2086.03
# Processing: cmaq5.2/rcp8.5/extr/2040ei_v6_cb05v2_ref_RCP8.5.combine.aconc.2086.04
# cmaq5.2/rcp8.5/extr/2040ei_v6_cb05v2_ref_RCP8.5.combine.aconc.2086.04
# Processing: cmaq5.2/rcp8.5/extr/2040ei_v6_cb05v2_ref_RCP8.5.combine.aconc.2086.05
# cmaq5.2/rcp8.5/extr/2040ei_v6_cb05v2_ref_RCP8.5.combine.aconc.2086.05
# Processing: cmaq5.2/rcp8.5/extr/2040ei_v6_cb05v2_ref_RCP8.5.combine.aconc.2086.06
# cmaq5.2/rcp8.5/extr/2040ei_v6_cb05v2_ref_RCP8.5.combine.aconc.2086.06
# ...
