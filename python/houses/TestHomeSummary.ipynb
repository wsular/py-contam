# %% [markdown]
# # Summary plots for contam output for WSU test homes

# %%
# %pylab inline 

import pandas as pd
from socket import gethostname

hostname = gethostname()
if hostname.rfind('gaia')>=0:
    d = '/mnt/data/lima/iaq/houses/outdoors/'
else:
    d = '/Users/vonw/data/iaq/houses/test_homes/'
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### Define test homes and separate by season

# %%
houses = ['h002_summer',
          'h002_winter',
          'h003_summer',
          'h003_winter',
          'h004_summer',
          'h004_winter',
          'h005_summer',
          'h006_summer',
#          'h006_winter',
          'h007_summer',
          'h007_winter',
          'h008_summer',
          'h008_winter',
          'h009_summer',
          'h009_winter',
          'h010_summer',
          'h010_winter']

summer = []
winter = []
for house in houses:
    if house.rfind('summer')>=0:
        summer.append(house)
    else:
        winter.append(house)

# %% [markdown]
# ## Test Home Temperatures

# %%
T = pd.concat([pd.read_hdf(d+'houses.hdf', 'h002_summer/T'),
               pd.read_hdf(d+'houses.hdf', 'h002_winter/T'),
               pd.read_hdf(d+'houses.hdf', 'h003_summer/T'),
               pd.read_hdf(d+'houses.hdf', 'h003_winter/T'),
               pd.read_hdf(d+'houses.hdf', 'h004_summer/T'),
               pd.read_hdf(d+'houses.hdf', 'h004_winter/T'),
               pd.read_hdf(d+'houses.hdf', 'h005_summer/T'),
               pd.read_hdf(d+'houses.hdf', 'h006_summer/T'),
#               pd.read_hdf(d+'houses.hdf', 'h006_winter/T'),
               pd.read_hdf(d+'houses.hdf', 'h007_summer/T'),
               pd.read_hdf(d+'houses.hdf', 'h007_winter/T'),
               pd.read_hdf(d+'houses.hdf', 'h008_summer/T'),
               pd.read_hdf(d+'houses.hdf', 'h008_winter/T'),
               pd.read_hdf(d+'houses.hdf', 'h009_summer/T'),
               pd.read_hdf(d+'houses.hdf', 'h009_winter/T'),
               pd.read_hdf(d+'houses.hdf', 'h010_summer/T'),
               pd.read_hdf(d+'houses.hdf', 'h010_winter/T')],keys=houses)

# %%
figure(figsize=(14,8))
T.loc[summer].groupby(level=0).hist(histtype='step', linewidth=2)
xlabel('Temperature (C)')
ylabel('Number of Occurrences')
title('Test Home Temperatures for Summer')
legend(summer, loc='best')

# %%
figure(figsize=(14,8))
T.loc[winter].groupby(level=0).hist(histtype='step', linewidth=2)
xlabel('Temperature (C)')
ylabel('Number of Occurrences')
title('Test Home Temperatures for Winter')
legend(winter, loc='best')

# %% [markdown]
# ## Test Home Wind Speeds

# %%
W = pd.concat([pd.read_hdf(d+'houses.hdf', 'h002_summer/W'),
               pd.read_hdf(d+'houses.hdf', 'h002_winter/W'),
               pd.read_hdf(d+'houses.hdf', 'h003_summer/W'),
               pd.read_hdf(d+'houses.hdf', 'h003_winter/W'),
               pd.read_hdf(d+'houses.hdf', 'h004_summer/W'),
               pd.read_hdf(d+'houses.hdf', 'h004_winter/W'),
               pd.read_hdf(d+'houses.hdf', 'h005_summer/W'),
               pd.read_hdf(d+'houses.hdf', 'h006_summer/W'),
#               pd.read_hdf(d+'houses.hdf', 'h006_winter/W'),
               pd.read_hdf(d+'houses.hdf', 'h007_summer/W'),
               pd.read_hdf(d+'houses.hdf', 'h007_winter/W'),
               pd.read_hdf(d+'houses.hdf', 'h008_summer/W'),
               pd.read_hdf(d+'houses.hdf', 'h008_winter/W'),
               pd.read_hdf(d+'houses.hdf', 'h009_summer/W'),
               pd.read_hdf(d+'houses.hdf', 'h009_winter/W'),
               pd.read_hdf(d+'houses.hdf', 'h010_summer/W'),
               pd.read_hdf(d+'houses.hdf', 'h010_winter/W')],keys=houses)

# %%
figure(figsize=(14,8))
W.loc[summer].groupby(level=0).hist(histtype='step', linewidth=2)
xlabel('Wind Speed (m s-1)')
ylabel('Number of Occurrences')
title('Test Home Wind Speeds for Summer')
legend(summer, loc='best')

# %%
figure(figsize=(14,8))
W.loc[winter].groupby(level=0).hist(histtype='step', linewidth=2)
xlabel('Wind Speed (m s-1)')
ylabel('Number of Occurrences')
title('Test Home Wind Speeds for Winter')
legend(winter, loc='best')

# %% [markdown]
# ## Test Home Ozone

# %%
o3 = pd.concat([pd.read_hdf(d+'houses.hdf', 'h002_summer/octm1'),
               pd.read_hdf(d+'houses.hdf', 'h002_winter/octm1'),
               pd.read_hdf(d+'houses.hdf', 'h003_summer/octm1'),
               pd.read_hdf(d+'houses.hdf', 'h003_winter/octm1'),
               pd.read_hdf(d+'houses.hdf', 'h004_summer/octm1'),
               pd.read_hdf(d+'houses.hdf', 'h004_winter/octm1'),
               pd.read_hdf(d+'houses.hdf', 'h005_summer/octm1'),
               pd.read_hdf(d+'houses.hdf', 'h006_summer/octm1'),
#               pd.read_hdf(d+'houses.hdf', 'h006_winter/octm1'),
               pd.read_hdf(d+'houses.hdf', 'h007_summer/octm1'),
               pd.read_hdf(d+'houses.hdf', 'h007_winter/octm1'),
               pd.read_hdf(d+'houses.hdf', 'h008_summer/octm1'),
               pd.read_hdf(d+'houses.hdf', 'h008_winter/octm1'),
               pd.read_hdf(d+'houses.hdf', 'h009_summer/octm1'),
               pd.read_hdf(d+'houses.hdf', 'h009_winter/octm1'),
               pd.read_hdf(d+'houses.hdf', 'h010_summer/octm1'),
               pd.read_hdf(d+'houses.hdf', 'h010_winter/octm1')],keys=houses)

# %%
figure(figsize=(14,8))
o3.loc[summer].groupby(level=0).hist(histtype='step', linewidth=2)
xlabel('Ozone (ppb)')
ylabel('Number of Occurrences')
title('Test Home Ozone for Summer')
legend(summer, loc='best')

# %%
figure(figsize=(14,8))
o3.loc[winter].groupby(level=0).hist(histtype='step', linewidth=2)
xlabel('Ozone (ppb)')
ylabel('Number of Occurrences')
title('Test Home Ozone for Winter')
legend(winter, loc='best')

# %% [markdown]
# ## Test Home PM2.5

# %%
pm = pd.concat([pd.read_hdf(d+'houses.hdf', 'h002_summer/octm2'),
               pd.read_hdf(d+'houses.hdf', 'h002_winter/octm2'),
               pd.read_hdf(d+'houses.hdf', 'h003_summer/octm2'),
               pd.read_hdf(d+'houses.hdf', 'h003_winter/octm2'),
               pd.read_hdf(d+'houses.hdf', 'h004_summer/octm2'),
               pd.read_hdf(d+'houses.hdf', 'h004_winter/octm2'),
               pd.read_hdf(d+'houses.hdf', 'h005_summer/octm2'),
               pd.read_hdf(d+'houses.hdf', 'h006_summer/octm2'),
#               pd.read_hdf(d+'houses.hdf', 'h006_winter/octm2'),
               pd.read_hdf(d+'houses.hdf', 'h007_summer/octm2'),
               pd.read_hdf(d+'houses.hdf', 'h007_winter/octm2'),
               pd.read_hdf(d+'houses.hdf', 'h008_summer/octm2'),
               pd.read_hdf(d+'houses.hdf', 'h008_winter/octm2'),
               pd.read_hdf(d+'houses.hdf', 'h009_summer/octm2'),
               pd.read_hdf(d+'houses.hdf', 'h009_winter/octm2'),
               pd.read_hdf(d+'houses.hdf', 'h010_summer/octm2'),
               pd.read_hdf(d+'houses.hdf', 'h010_winter/octm2')],keys=houses)

# %%
figure(figsize=(14,8))
pm.loc[summer].groupby(level=0).hist(histtype='step', linewidth=2)
xlabel('PM2.5 (ug m-3)')
ylabel('Number of Occurrences')
title('Test Home PM2.5 for Summer')
legend(summer, loc='best')

# %%
figure(figsize=(14,8))
pm.loc[winter].groupby(level=0).hist(histtype='step', linewidth=2)
xlabel('PM2.5 (ug m-3)')
ylabel('Number of Occurrences')
title('Test Home PM2.5 for winter')
legend(winter, loc='best')

# %% [markdown]
# ## Test Home HCHO

# %%
ch2o = pd.concat([pd.read_hdf(d+'houses.hdf', 'h002_summer/octm3'),
                  pd.read_hdf(d+'houses.hdf', 'h002_winter/octm3'),
                  pd.read_hdf(d+'houses.hdf', 'h003_summer/octm3'),
                  pd.read_hdf(d+'houses.hdf', 'h003_winter/octm3'),
                  pd.read_hdf(d+'houses.hdf', 'h004_summer/octm3'),
                  pd.read_hdf(d+'houses.hdf', 'h004_winter/octm3'),
                  pd.read_hdf(d+'houses.hdf', 'h005_summer/octm3'),
                  pd.read_hdf(d+'houses.hdf', 'h006_summer/octm3'),
#                  pd.read_hdf(d+'houses.hdf', 'h006_winter/octm3'),
                  pd.read_hdf(d+'houses.hdf', 'h007_summer/octm3'),
                  pd.read_hdf(d+'houses.hdf', 'h007_winter/octm3'),
                  pd.read_hdf(d+'houses.hdf', 'h008_summer/octm3'),
                  pd.read_hdf(d+'houses.hdf', 'h008_winter/octm3'),
                  pd.read_hdf(d+'houses.hdf', 'h009_summer/octm3'),
                  pd.read_hdf(d+'houses.hdf', 'h009_winter/octm3'),
                  pd.read_hdf(d+'houses.hdf', 'h010_summer/octm3'),
                  pd.read_hdf(d+'houses.hdf', 'h010_winter/octm3')],keys=houses)

# %%
figure(figsize=(14,8))
ch2o.loc[summer].groupby(level=0).hist(histtype='step', linewidth=2)
xlabel('Formaldehyde (pbbv)')
ylabel('Number of Occurrences')
title('Test Home Formaldehyde for Summer')
legend(summer, loc='best')

# %%
figure(figsize=(14,8))
ch2o.loc[winter].groupby(level=0).hist(histtype='step', linewidth=2)
xlabel('Formaldehyde (pbbv)')
ylabel('Number of Occurrences')
title('Test Home Formaldehyde for Winter')
legend(winter, loc='best')

# %% [markdown]
# ## Test Home ACH

# %%
ach  = pd.concat([pd.read_hdf(d+'houses.hdf', 'h002_summer/ach'),
                  pd.read_hdf(d+'houses.hdf', 'h002_winter/ach'),
                  pd.read_hdf(d+'houses.hdf', 'h003_summer/ach'),
                  pd.read_hdf(d+'houses.hdf', 'h003_winter/ach'),
                  pd.read_hdf(d+'houses.hdf', 'h004_summer/ach'),
                  pd.read_hdf(d+'houses.hdf', 'h004_winter/ach'),
                  pd.read_hdf(d+'houses.hdf', 'h005_summer/ach'),
                  pd.read_hdf(d+'houses.hdf', 'h006_summer/ach'),
#                  pd.read_hdf(d+'houses.hdf', 'h006_winter/ach'),
                  pd.read_hdf(d+'houses.hdf', 'h007_summer/ach'),
                  pd.read_hdf(d+'houses.hdf', 'h007_winter/ach'),
                  pd.read_hdf(d+'houses.hdf', 'h008_summer/ach'),
                  pd.read_hdf(d+'houses.hdf', 'h008_winter/ach'),
                  pd.read_hdf(d+'houses.hdf', 'h009_summer/ach'),
                  pd.read_hdf(d+'houses.hdf', 'h009_winter/ach'),
                  pd.read_hdf(d+'houses.hdf', 'h010_summer/ach'),
                  pd.read_hdf(d+'houses.hdf', 'h010_winter/ach')],keys=houses)

# %%
figure(figsize=(14,8))
ach.loc[summer].groupby(level=0).hist(histtype='step', linewidth=2)
xlabel('ACH')
ylabel('Number of Occurrences')
title('Test Home ACH for Summer')
legend(summer, loc='best')

# %%
figure(figsize=(14,8))
ach.loc[winter].groupby(level=0).hist(histtype='step', linewidth=2)
xlabel('ACH')
ylabel('Number of Occurrences')
title('Test Home ACH for Winter')
legend(winter, loc='best')
